# %%
import numpy as np
import cupy as cp

# %%
x_gpu = cp.array([1, 2, 3])
x_cpu = np.array([1, 2, 3])

# %%
# %timeit np.linalg.norm(x_cpu)
# Out:
# 1.34 μs ± 5.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# run norm on the arrays and timeit the results
# %timeit cp.linalg.norm(x_gpu)
# Out:
# 29.2 μs ± 143 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
x_on_gpu0 = cp.array([1, 2, 3, 4, 5])
x_on_gpu0.device
# Out:
# <CUDA Device 0>

# %%
import cupy as cp
import cupyx.scipy.fft as cufft

# %%
a = cp.random.random(100000).astype(cp.complex64)
# %timeit cufft.fft(a)
# Out:
# 12.9 μs ± 3.11 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# FFT of an array using scipy and timeit 
a = np.random.random(100000).astype(np.complex64)
# %timeit scipy.fft.fft(a)
# Out:
# 770 μs ± 45.4 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
