# %%
from ratinabox.Environment import Environment
from ratinabox.Agent import Agent
from ratinabox.Neurons import PlaceCells

# %%
Env = Environment()
Ag = Agent(Env)
PCs = PlaceCells(Ag, params= {"n": 1000000})
for i in range(int(60 / Ag.dt)):
    Ag.update()
    PCs.update()

# %%
PCs.firingrate.device
# Out:
# <CUDA Device 0>

# %%
# get size of the firing rate array in MBs
PCs.firingrate.size * PCs.firingrate.dtype.itemsize / 1024 / 1024
# Out:
# 7.62939453125
